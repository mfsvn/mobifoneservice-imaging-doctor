# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from keras import backend as K
from keras.layers import Layer,InputSpec
import keras.layers as kl
from glob import glob
from sklearn.metrics import roc_curve, auc
from keras.preprocessing import image
from tensorflow.keras.models import Sequential
from sklearn.metrics import roc_auc_score
from tensorflow.keras import callbacks 
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from  matplotlib import pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras.layers import concatenate,Dense, Conv2D, MaxPooling2D, Flatten,Input,Activation,add,AveragePooling2D,BatchNormalization,Dropout
# %matplotlib inline
import shutil
from sklearn.metrics import  precision_score, recall_score, accuracy_score,classification_report ,confusion_matrix
from tensorflow.python.platform import build_info as tf_build_info
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
data_pd = pd.read_csv('/content/drive/MyDrive/ColabData/HAM10000/csv/HAM10000_metadata.csv')
data_pd.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset
# 0  vidir_modern
# 1  vidir_modern
# 2  vidir_modern
# 3  vidir_modern
# 4  vidir_modern

# %%
# from zipfile import ZipFile
# filename="/content/drive/MyDrive/ColabData/HAM10000/images/HAM10000_Images_All.zip"
# with ZipFile(filename,'r') as zip:
#   zip.extractall("/content/drive/MyDrive/ColabData/HAM10000/images/")
#   print("done")

# %%
image_dir        = "/content/drive/MyDrive/ColabData/HAM10000/images"
metadata_csv     = "/content/drive/MyDrive/ColabData/HAM10000/csv/HAM10000_metadata.csv"
path_splitter    = "/"
images_type      = ".jpg"

# %%
train_dir = os.path.join(image_dir, 'train_dir\\')
test_dir = os.path.join(image_dir, 'test_dir\\')

df_count = data_pd.groupby('lesion_id').count()
df_count.head()

df_count = df_count[df_count['dx'] == 1]

# %%
df_count.reset_index(inplace=True)

unique = set(df_count['lesion_id'])
def duplicates(x):
    if x in unique:
        return 'no' 
    else:
        return 'duplicates'
data_pd['is_duplicate'] = data_pd['lesion_id'].apply(duplicates)
data_pd.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset is_duplicate
# 0  vidir_modern   duplicates
# 1  vidir_modern   duplicates
# 2  vidir_modern   duplicates
# 3  vidir_modern   duplicates
# 4  vidir_modern   duplicates

# %%
df_count = data_pd[data_pd['is_duplicate'] == 'no']

# %%
train, test_df = train_test_split(df_count, test_size=0.15, stratify=df_count['dx'])

test_data = set(test_df['image_id'])
def identify_trainOrtest(x):
    if str(x) in test_data:
        return 'test'
    else:
        return 'train'
    
#creating train_df
data_pd['train_test_split'] = data_pd['image_id'].apply(identify_trainOrtest)
train_df = data_pd[data_pd['train_test_split'] == 'train']
train_df.head()

# Image id of train and test images
train_list = list(train_df['image_id'])
test_list = list(test_df['image_id'])

# Set the image_id as the index in data_pd
data_pd.set_index('image_id', inplace=True)

# %%
train_dir = os.path.join(image_dir, 'train_dir/')
test_dir = os.path.join(image_dir, 'test_dir/')

# %%
batch_size = 16

# %%
train_path  = train_dir
test_path=test_dir

# %%
datagen=ImageDataGenerator(preprocessing_function=tf.keras.applications.inception_resnet_v2.preprocess_input)

# %%
image_size = 299
print("\nTrain Batches: ")
train_batches = datagen.flow_from_directory(directory=train_path,
                                            target_size=(image_size,image_size),
                                            batch_size=batch_size,
                                            shuffle=True)

print("\nTest Batches: ")
test_batches =datagen.flow_from_directory(test_path,
                                           target_size=(image_size,image_size),
                                           batch_size=batch_size,
                                           shuffle=False)
# Out:
# Train Batches:
# Found 52411 images belonging to 7 classes.
#
# Test Batches:
# Found 828 images belonging to 7 classes.

# %%
#Soft Attention

from keras import backend as K
from keras.layers import Layer,InputSpec
import keras.layers as kl
import tensorflow as tf



class SoftAttention(Layer):
    def __init__(self,ch,m,concat_with_x=False,aggregate=False,**kwargs):
        self.channels=int(ch)
        self.multiheads = m
        self.aggregate_channels = aggregate
        self.concat_input_with_scaled = concat_with_x

        
        super(SoftAttention,self).__init__(**kwargs)

    def build(self,input_shape):

        self.i_shape = input_shape

        kernel_shape_conv3d = (self.channels, 3, 3) + (1, self.multiheads) # DHWC
    
        self.out_attention_maps_shape = input_shape[0:1]+(self.multiheads,)+input_shape[1:-1]
        
        if self.aggregate_channels==False:

            self.out_features_shape = input_shape[:-1]+(input_shape[-1]+(input_shape[-1]*self.multiheads),)
        else:
            if self.concat_input_with_scaled:
                self.out_features_shape = input_shape[:-1]+(input_shape[-1]*2,)
            else:
                self.out_features_shape = input_shape
        

        self.kernel_conv3d = self.add_weight(shape=kernel_shape_conv3d,
                                        initializer='he_uniform',
                                        name='kernel_conv3d')
        self.bias_conv3d = self.add_weight(shape=(self.multiheads,),
                                      initializer='zeros',
                                      name='bias_conv3d')

        super(SoftAttention, self).build(input_shape)

    def call(self, x):

        exp_x = K.expand_dims(x,axis=-1)

        c3d = K.conv3d(exp_x,
                     kernel=self.kernel_conv3d,
                     strides=(1,1,self.i_shape[-1]), padding='same', data_format='channels_last')
        conv3d = K.bias_add(c3d,
                        self.bias_conv3d)
        conv3d = kl.Activation('relu')(conv3d)

        conv3d = K.permute_dimensions(conv3d,pattern=(0,4,1,2,3))

        
        conv3d = K.squeeze(conv3d, axis=-1)
        conv3d = K.reshape(conv3d,shape=(-1, self.multiheads ,self.i_shape[1]*self.i_shape[2]))

        softmax_alpha = K.softmax(conv3d, axis=-1) 
        softmax_alpha = kl.Reshape(target_shape=(self.multiheads, self.i_shape[1],self.i_shape[2]))(softmax_alpha)

        
        if self.aggregate_channels==False:
            exp_softmax_alpha = K.expand_dims(softmax_alpha, axis=-1)       
            exp_softmax_alpha = K.permute_dimensions(exp_softmax_alpha,pattern=(0,2,3,1,4))
   
            x_exp = K.expand_dims(x,axis=-2)
   
            u = kl.Multiply()([exp_softmax_alpha, x_exp])   
  
            u = kl.Reshape(target_shape=(self.i_shape[1],self.i_shape[2],u.shape[-1]*u.shape[-2]))(u)

        else:
            exp_softmax_alpha = K.permute_dimensions(softmax_alpha,pattern=(0,2,3,1))

            exp_softmax_alpha = K.sum(exp_softmax_alpha,axis=-1)

            exp_softmax_alpha = K.expand_dims(exp_softmax_alpha, axis=-1)

            u = kl.Multiply()([exp_softmax_alpha, x])   

        if self.concat_input_with_scaled:
            o = kl.Concatenate(axis=-1)([u,x])
        else:
            o = u
        
        return [o, softmax_alpha]

    def compute_output_shape(self, input_shape): 
        return [self.out_features_shape, self.out_attention_maps_shape]

    
    def get_config(self):
        return super(SoftAttention,self).get_config()

# %%
shape = (299, 299, 3) 
inputs = tf.keras.Input(shape=shape, name="input")
x = tf.keras.layers.RandomFlip(mode="horizontal_and_vertical")(inputs)
x = tf.keras.layers.RandomRotation(0.2)(x)
x = tf.keras.layers.RandomTranslation(height_factor=0.2, width_factor=0.2, fill_mode="wrap")(x)
x = tf.keras.layers.RandomContrast(factor=0.2)(x)
x = tf.keras.layers.RandomHeight(factor=0.2)(x)
x = tf.keras.layers.RandomWidth(factor=0.2)(x)
x = tf.keras.layers.RandomZoom(0.3, 0.4)(x)  
x = tf.keras.layers.RandomCrop(100, 100)(x)

irv2 = tf.keras.applications.InceptionResNetV2(
    include_top=False,
    weights="imagenet",
    input_tensor=x,
    input_shape=None,
    pooling=None,
    classifier_activation="softmax", 
     

)
 
# Excluding the last 28 layers of the model.
conv = irv2.layers[-33].output   

attention_layer,map2 = SoftAttention(aggregate=True,m=16,concat_with_x=False,ch=int(conv.shape[-1]),name='soft_attention')(conv)
attention_layer=(MaxPooling2D(pool_size=(2, 2),padding="same")(attention_layer))
conv=(MaxPooling2D(pool_size=(2, 2),padding="same")(conv))

conv = concatenate([conv,attention_layer])
conv = Activation('relu')(conv)
conv = Dropout(0.5)(conv)

output = Flatten()(conv)
output = Dense(7, activation='softmax')(output)
model = Model(inputs=inputs, outputs=output)

model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 299, 299, 3  0           []
#                                 )]
#
#  random_flip_4 (RandomFlip)     (None, 299, 299, 3)  0           ['input[0][0]']
#
#  random_rotation_3 (RandomRotat  (None, 299, 299, 3)  0          ['random_flip_4[0][0]']
#  ion)
#
#  random_translation_3 (RandomTr  (None, 299, 299, 3)  0          ['random_rotation_3[0][0]']
#  anslation)
#
#  random_contrast_3 (RandomContr  (None, 299, 299, 3)  0          ['random_translation_3[0][0]']
#  ast)
#
#  random_height_3 (RandomHeight)  (None, 299, 299, 3)  0          ['random_contrast_3[0][0]']
#
#  random_width_3 (RandomWidth)   (None, 299, 299, 3)  0           ['random_height_3[0][0]']
#
#  random_zoom_3 (RandomZoom)     (None, 299, 299, 3)  0           ['random_width_3[0][0]']
#
#  random_crop_2 (RandomCrop)     (None, 100, 100, 3)  0           ['random_zoom_3[0][0]']
#
#  conv2d_812 (Conv2D)            (None, 49, 49, 32)   864         ['random_crop_2[0][0]']
#
#  batch_normalization_812 (Batch  (None, 49, 49, 32)  96          ['conv2d_812[0][0]']
#  Normalization)
#
#  activation_815 (Activation)    (None, 49, 49, 32)   0           ['batch_normalization_812[0][0]']
#
#  conv2d_813 (Conv2D)            (None, 47, 47, 32)   9216        ['activation_815[0][0]']
#
#  batch_normalization_813 (Batch  (None, 47, 47, 32)  96          ['conv2d_813[0][0]']
#  Normalization)
#
#  activation_816 (Activation)    (None, 47, 47, 32)   0           ['batch_normalization_813[0][0]']
#
#  conv2d_814 (Conv2D)            (None, 47, 47, 64)   18432       ['activation_816[0][0]']
#
#  batch_normalization_814 (Batch  (None, 47, 47, 64)  192         ['conv2d_814[0][0]']
#  Normalization)
#
#  activation_817 (Activation)    (None, 47, 47, 64)   0           ['batch_normalization_814[0][0]']
#
#  max_pooling2d_22 (MaxPooling2D  (None, 23, 23, 64)  0           ['activation_817[0][0]']
#  )
#
#  conv2d_815 (Conv2D)            (None, 23, 23, 80)   5120        ['max_pooling2d_22[0][0]']
#
#  batch_normalization_815 (Batch  (None, 23, 23, 80)  240         ['conv2d_815[0][0]']
#  Normalization)
#
#  activation_818 (Activation)    (None, 23, 23, 80)   0           ['batch_normalization_815[0][0]']
#
#  conv2d_816 (Conv2D)            (None, 21, 21, 192)  138240      ['activation_818[0][0]']
#
#  batch_normalization_816 (Batch  (None, 21, 21, 192)  576        ['conv2d_816[0][0]']
#  Normalization)
#
#  activation_819 (Activation)    (None, 21, 21, 192)  0           ['batch_normalization_816[0][0]']
#
#  max_pooling2d_23 (MaxPooling2D  (None, 10, 10, 192)  0          ['activation_819[0][0]']
#  )
#
#  conv2d_820 (Conv2D)            (None, 10, 10, 64)   12288       ['max_pooling2d_23[0][0]']
#
#  batch_normalization_820 (Batch  (None, 10, 10, 64)  192         ['conv2d_820[0][0]']
#  Normalization)
#
#  activation_823 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_820[0][0]']
#
#  conv2d_818 (Conv2D)            (None, 10, 10, 48)   9216        ['max_pooling2d_23[0][0]']
#
#  conv2d_821 (Conv2D)            (None, 10, 10, 96)   55296       ['activation_823[0][0]']
#
#  batch_normalization_818 (Batch  (None, 10, 10, 48)  144         ['conv2d_818[0][0]']
#  Normalization)
#
#  batch_normalization_821 (Batch  (None, 10, 10, 96)  288         ['conv2d_821[0][0]']
#  Normalization)
#
#  activation_821 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_818[0][0]']
#
#  activation_824 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_821[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 10, 10, 192)  0          ['max_pooling2d_23[0][0]']
#  oling2D)
#
#  conv2d_817 (Conv2D)            (None, 10, 10, 96)   18432       ['max_pooling2d_23[0][0]']
#
#  conv2d_819 (Conv2D)            (None, 10, 10, 64)   76800       ['activation_821[0][0]']
#
#  conv2d_822 (Conv2D)            (None, 10, 10, 96)   82944       ['activation_824[0][0]']
#
#  conv2d_823 (Conv2D)            (None, 10, 10, 64)   12288       ['average_pooling2d_4[0][0]']
#
#  batch_normalization_817 (Batch  (None, 10, 10, 96)  288         ['conv2d_817[0][0]']
#  Normalization)
#
#  batch_normalization_819 (Batch  (None, 10, 10, 64)  192         ['conv2d_819[0][0]']
#  Normalization)
#
#  batch_normalization_822 (Batch  (None, 10, 10, 96)  288         ['conv2d_822[0][0]']
#  Normalization)
#
#  batch_normalization_823 (Batch  (None, 10, 10, 64)  192         ['conv2d_823[0][0]']
#  Normalization)
#
#  activation_820 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_817[0][0]']
#
#  activation_822 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_819[0][0]']
#
#  activation_825 (Activation)    (None, 10, 10, 96)   0           ['batch_normalization_822[0][0]']
#
#  activation_826 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_823[0][0]']
#
#  mixed_5b (Concatenate)         (None, 10, 10, 320)  0           ['activation_820[0][0]',
#                                                                   'activation_822[0][0]',
#                                                                   'activation_825[0][0]',
#                                                                   'activation_826[0][0]']
#
#  conv2d_827 (Conv2D)            (None, 10, 10, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_827 (Batch  (None, 10, 10, 32)  96          ['conv2d_827[0][0]']
#  Normalization)
#
#  activation_830 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_827[0][0]']
#
#  conv2d_825 (Conv2D)            (None, 10, 10, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_828 (Conv2D)            (None, 10, 10, 48)   13824       ['activation_830[0][0]']
#
#  batch_normalization_825 (Batch  (None, 10, 10, 32)  96          ['conv2d_825[0][0]']
#  Normalization)
#
#  batch_normalization_828 (Batch  (None, 10, 10, 48)  144         ['conv2d_828[0][0]']
#  Normalization)
#
#  activation_828 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_825[0][0]']
#
#  activation_831 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_828[0][0]']
#
#  conv2d_824 (Conv2D)            (None, 10, 10, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_826 (Conv2D)            (None, 10, 10, 32)   9216        ['activation_828[0][0]']
#
#  conv2d_829 (Conv2D)            (None, 10, 10, 64)   27648       ['activation_831[0][0]']
#
#  batch_normalization_824 (Batch  (None, 10, 10, 32)  96          ['conv2d_824[0][0]']
#  Normalization)
#
#  batch_normalization_826 (Batch  (None, 10, 10, 32)  96          ['conv2d_826[0][0]']
#  Normalization)
#
#  batch_normalization_829 (Batch  (None, 10, 10, 64)  192         ['conv2d_829[0][0]']
#  Normalization)
#
#  activation_827 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_824[0][0]']
#
#  activation_829 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_826[0][0]']
#
#  activation_832 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_829[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_827[0][0]',
#                                                                   'activation_829[0][0]',
#                                                                   'activation_832[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 10, 10, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 10, 10, 320)  0           ['block35_1[0][0]']
#
#  conv2d_833 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_833 (Batch  (None, 10, 10, 32)  96          ['conv2d_833[0][0]']
#  Normalization)
#
#  activation_836 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_833[0][0]']
#
#  conv2d_831 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_834 (Conv2D)            (None, 10, 10, 48)   13824       ['activation_836[0][0]']
#
#  batch_normalization_831 (Batch  (None, 10, 10, 32)  96          ['conv2d_831[0][0]']
#  Normalization)
#
#  batch_normalization_834 (Batch  (None, 10, 10, 48)  144         ['conv2d_834[0][0]']
#  Normalization)
#
#  activation_834 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_831[0][0]']
#
#  activation_837 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_834[0][0]']
#
#  conv2d_830 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_832 (Conv2D)            (None, 10, 10, 32)   9216        ['activation_834[0][0]']
#
#  conv2d_835 (Conv2D)            (None, 10, 10, 64)   27648       ['activation_837[0][0]']
#
#  batch_normalization_830 (Batch  (None, 10, 10, 32)  96          ['conv2d_830[0][0]']
#  Normalization)
#
#  batch_normalization_832 (Batch  (None, 10, 10, 32)  96          ['conv2d_832[0][0]']
#  Normalization)
#
#  batch_normalization_835 (Batch  (None, 10, 10, 64)  192         ['conv2d_835[0][0]']
#  Normalization)
#
#  activation_833 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_830[0][0]']
#
#  activation_835 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_832[0][0]']
#
#  activation_838 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_835[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_833[0][0]',
#                                                                   'activation_835[0][0]',
#                                                                   'activation_838[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 10, 10, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 10, 10, 320)  0           ['block35_2[0][0]']
#
#  conv2d_839 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_839 (Batch  (None, 10, 10, 32)  96          ['conv2d_839[0][0]']
#  Normalization)
#
#  activation_842 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_839[0][0]']
#
#  conv2d_837 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_840 (Conv2D)            (None, 10, 10, 48)   13824       ['activation_842[0][0]']
#
#  batch_normalization_837 (Batch  (None, 10, 10, 32)  96          ['conv2d_837[0][0]']
#  Normalization)
#
#  batch_normalization_840 (Batch  (None, 10, 10, 48)  144         ['conv2d_840[0][0]']
#  Normalization)
#
#  activation_840 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_837[0][0]']
#
#  activation_843 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_840[0][0]']
#
#  conv2d_836 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_838 (Conv2D)            (None, 10, 10, 32)   9216        ['activation_840[0][0]']
#
#  conv2d_841 (Conv2D)            (None, 10, 10, 64)   27648       ['activation_843[0][0]']
#
#  batch_normalization_836 (Batch  (None, 10, 10, 32)  96          ['conv2d_836[0][0]']
#  Normalization)
#
#  batch_normalization_838 (Batch  (None, 10, 10, 32)  96          ['conv2d_838[0][0]']
#  Normalization)
#
#  batch_normalization_841 (Batch  (None, 10, 10, 64)  192         ['conv2d_841[0][0]']
#  Normalization)
#
#  activation_839 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_836[0][0]']
#
#  activation_841 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_838[0][0]']
#
#  activation_844 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_841[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_839[0][0]',
#                                                                   'activation_841[0][0]',
#                                                                   'activation_844[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 10, 10, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 10, 10, 320)  0           ['block35_3[0][0]']
#
#  conv2d_845 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_845 (Batch  (None, 10, 10, 32)  96          ['conv2d_845[0][0]']
#  Normalization)
#
#  activation_848 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_845[0][0]']
#
#  conv2d_843 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_846 (Conv2D)            (None, 10, 10, 48)   13824       ['activation_848[0][0]']
#
#  batch_normalization_843 (Batch  (None, 10, 10, 32)  96          ['conv2d_843[0][0]']
#  Normalization)
#
#  batch_normalization_846 (Batch  (None, 10, 10, 48)  144         ['conv2d_846[0][0]']
#  Normalization)
#
#  activation_846 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_843[0][0]']
#
#  activation_849 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_846[0][0]']
#
#  conv2d_842 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_844 (Conv2D)            (None, 10, 10, 32)   9216        ['activation_846[0][0]']
#
#  conv2d_847 (Conv2D)            (None, 10, 10, 64)   27648       ['activation_849[0][0]']
#
#  batch_normalization_842 (Batch  (None, 10, 10, 32)  96          ['conv2d_842[0][0]']
#  Normalization)
#
#  batch_normalization_844 (Batch  (None, 10, 10, 32)  96          ['conv2d_844[0][0]']
#  Normalization)
#
#  batch_normalization_847 (Batch  (None, 10, 10, 64)  192         ['conv2d_847[0][0]']
#  Normalization)
#
#  activation_845 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_842[0][0]']
#
#  activation_847 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_844[0][0]']
#
#  activation_850 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_847[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_845[0][0]',
#                                                                   'activation_847[0][0]',
#                                                                   'activation_850[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 10, 10, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 10, 10, 320)  0           ['block35_4[0][0]']
#
#  conv2d_851 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_851 (Batch  (None, 10, 10, 32)  96          ['conv2d_851[0][0]']
#  Normalization)
#
#  activation_854 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_851[0][0]']
#
#  conv2d_849 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_852 (Conv2D)            (None, 10, 10, 48)   13824       ['activation_854[0][0]']
#
#  batch_normalization_849 (Batch  (None, 10, 10, 32)  96          ['conv2d_849[0][0]']
#  Normalization)
#
#  batch_normalization_852 (Batch  (None, 10, 10, 48)  144         ['conv2d_852[0][0]']
#  Normalization)
#
#  activation_852 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_849[0][0]']
#
#  activation_855 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_852[0][0]']
#
#  conv2d_848 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_850 (Conv2D)            (None, 10, 10, 32)   9216        ['activation_852[0][0]']
#
#  conv2d_853 (Conv2D)            (None, 10, 10, 64)   27648       ['activation_855[0][0]']
#
#  batch_normalization_848 (Batch  (None, 10, 10, 32)  96          ['conv2d_848[0][0]']
#  Normalization)
#
#  batch_normalization_850 (Batch  (None, 10, 10, 32)  96          ['conv2d_850[0][0]']
#  Normalization)
#
#  batch_normalization_853 (Batch  (None, 10, 10, 64)  192         ['conv2d_853[0][0]']
#  Normalization)
#
#  activation_851 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_848[0][0]']
#
#  activation_853 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_850[0][0]']
#
#  activation_856 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_853[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_851[0][0]',
#                                                                   'activation_853[0][0]',
#                                                                   'activation_856[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 10, 10, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 10, 10, 320)  0           ['block35_5[0][0]']
#
#  conv2d_857 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_857 (Batch  (None, 10, 10, 32)  96          ['conv2d_857[0][0]']
#  Normalization)
#
#  activation_860 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_857[0][0]']
#
#  conv2d_855 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_858 (Conv2D)            (None, 10, 10, 48)   13824       ['activation_860[0][0]']
#
#  batch_normalization_855 (Batch  (None, 10, 10, 32)  96          ['conv2d_855[0][0]']
#  Normalization)
#
#  batch_normalization_858 (Batch  (None, 10, 10, 48)  144         ['conv2d_858[0][0]']
#  Normalization)
#
#  activation_858 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_855[0][0]']
#
#  activation_861 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_858[0][0]']
#
#  conv2d_854 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_856 (Conv2D)            (None, 10, 10, 32)   9216        ['activation_858[0][0]']
#
#  conv2d_859 (Conv2D)            (None, 10, 10, 64)   27648       ['activation_861[0][0]']
#
#  batch_normalization_854 (Batch  (None, 10, 10, 32)  96          ['conv2d_854[0][0]']
#  Normalization)
#
#  batch_normalization_856 (Batch  (None, 10, 10, 32)  96          ['conv2d_856[0][0]']
#  Normalization)
#
#  batch_normalization_859 (Batch  (None, 10, 10, 64)  192         ['conv2d_859[0][0]']
#  Normalization)
#
#  activation_857 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_854[0][0]']
#
#  activation_859 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_856[0][0]']
#
#  activation_862 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_859[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_857[0][0]',
#                                                                   'activation_859[0][0]',
#                                                                   'activation_862[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 10, 10, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 10, 10, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 10, 10, 320)  0           ['block35_6[0][0]']
#
#  conv2d_863 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_863 (Batch  (None, 10, 10, 32)  96          ['conv2d_863[0][0]']
#  Normalization)
#
#  activation_866 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_863[0][0]']
#
#  conv2d_861 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_864 (Conv2D)            (None, 10, 10, 48)   13824       ['activation_866[0][0]']
#
#  batch_normalization_861 (Batch  (None, 10, 10, 32)  96          ['conv2d_861[0][0]']
#  Normalization)
#
#  batch_normalization_864 (Batch  (None, 10, 10, 48)  144         ['conv2d_864[0][0]']
#  Normalization)
#
#  activation_864 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_861[0][0]']
#
#  activation_867 (Activation)    (None, 10, 10, 48)   0           ['batch_normalization_864[0][0]']
#
#  conv2d_860 (Conv2D)            (None, 10, 10, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_862 (Conv2D)            (None, 10, 10, 32)   9216        ['activation_864[0][0]']
#
#  conv2d_865 (Conv2D)            (None, 10, 10, 64)   27648       ['activation_867[0][0]']
#
#  batch_normalization_860 (Batch  (None, 10, 10, 32)  96          ['conv2d_860[0][0]']
#  Normalization)
#
#  batch_normalization_862 (Batch  (None, 10, 10, 32)  96          ['conv2d_862[0][0]']
#  Normalization)
#
#  batch_normalization_865 (Batch  (None, 10, 10, 64)  192         ['conv2d_865[0][0]']
#  Normalization)
#
#  activation_863 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_860[0][0]']
#
#  activation_865 (Activation)    (None, 10, 10, 32)   0           ['batch_normalization_862[0][0]']
#
#  activation_868 (Activation)    (None, 10, 10, 64)   0           ['batch_normalization_865[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 10, 10, 128)  0           ['activation_863[0][0]',
# ...
#  activation_997 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_994[0][0]']
#
#  block8_5_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_994[0][0]',
#                                                                   'activation_997[0][0]']
#
#  block8_5_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_5_mixed[0][0]']
#
#  block8_5 (Lambda)              (None, 1, 1, 2080)   0           ['block8_4_ac[0][0]',
#                                                                   'block8_5_conv[0][0]']
#
#  block8_5_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_5[0][0]']
#
#  conv2d_996 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_5_ac[0][0]']
#
#  batch_normalization_996 (Batch  (None, 1, 1, 192)   576         ['conv2d_996[0][0]']
#  Normalization)
#
#  activation_999 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_996[0][0]']
#
#  conv2d_997 (Conv2D)            (None, 1, 1, 224)    129024      ['activation_999[0][0]']
#
#  batch_normalization_997 (Batch  (None, 1, 1, 224)   672         ['conv2d_997[0][0]']
#  Normalization)
#
#  activation_1000 (Activation)   (None, 1, 1, 224)    0           ['batch_normalization_997[0][0]']
#
#  conv2d_995 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_5_ac[0][0]']
#
#  conv2d_998 (Conv2D)            (None, 1, 1, 256)    172032      ['activation_1000[0][0]']
#
#  batch_normalization_995 (Batch  (None, 1, 1, 192)   576         ['conv2d_995[0][0]']
#  Normalization)
#
#  batch_normalization_998 (Batch  (None, 1, 1, 256)   768         ['conv2d_998[0][0]']
#  Normalization)
#
#  activation_998 (Activation)    (None, 1, 1, 192)    0           ['batch_normalization_995[0][0]']
#
#  activation_1001 (Activation)   (None, 1, 1, 256)    0           ['batch_normalization_998[0][0]']
#
#  block8_6_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_998[0][0]',
#                                                                   'activation_1001[0][0]']
#
#  block8_6_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_6_mixed[0][0]']
#
#  block8_6 (Lambda)              (None, 1, 1, 2080)   0           ['block8_5_ac[0][0]',
#                                                                   'block8_6_conv[0][0]']
#
#  block8_6_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_6[0][0]']
#
#  conv2d_1000 (Conv2D)           (None, 1, 1, 192)    399360      ['block8_6_ac[0][0]']
#
#  batch_normalization_1000 (Batc  (None, 1, 1, 192)   576         ['conv2d_1000[0][0]']
#  hNormalization)
#
#  activation_1003 (Activation)   (None, 1, 1, 192)    0           ['batch_normalization_1000[0][0]'
#                                                                  ]
#
#  conv2d_1001 (Conv2D)           (None, 1, 1, 224)    129024      ['activation_1003[0][0]']
#
#  batch_normalization_1001 (Batc  (None, 1, 1, 224)   672         ['conv2d_1001[0][0]']
#  hNormalization)
#
#  activation_1004 (Activation)   (None, 1, 1, 224)    0           ['batch_normalization_1001[0][0]'
#                                                                  ]
#
#  conv2d_999 (Conv2D)            (None, 1, 1, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_1002 (Conv2D)           (None, 1, 1, 256)    172032      ['activation_1004[0][0]']
#
#  batch_normalization_999 (Batch  (None, 1, 1, 192)   576         ['conv2d_999[0][0]']
#  Normalization)
#
#  batch_normalization_1002 (Batc  (None, 1, 1, 256)   768         ['conv2d_1002[0][0]']
#  hNormalization)
#
#  activation_1002 (Activation)   (None, 1, 1, 192)    0           ['batch_normalization_999[0][0]']
#
#  activation_1005 (Activation)   (None, 1, 1, 256)    0           ['batch_normalization_1002[0][0]'
#                                                                  ]
#
#  block8_7_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_1002[0][0]',
#                                                                   'activation_1005[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 1, 1, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_1004 (Conv2D)           (None, 1, 1, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_1004 (Batc  (None, 1, 1, 192)   576         ['conv2d_1004[0][0]']
#  hNormalization)
#
#  activation_1007 (Activation)   (None, 1, 1, 192)    0           ['batch_normalization_1004[0][0]'
#                                                                  ]
#
#  conv2d_1005 (Conv2D)           (None, 1, 1, 224)    129024      ['activation_1007[0][0]']
#
#  batch_normalization_1005 (Batc  (None, 1, 1, 224)   672         ['conv2d_1005[0][0]']
#  hNormalization)
#
#  activation_1008 (Activation)   (None, 1, 1, 224)    0           ['batch_normalization_1005[0][0]'
#                                                                  ]
#
#  conv2d_1003 (Conv2D)           (None, 1, 1, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_1006 (Conv2D)           (None, 1, 1, 256)    172032      ['activation_1008[0][0]']
#
#  batch_normalization_1003 (Batc  (None, 1, 1, 192)   576         ['conv2d_1003[0][0]']
#  hNormalization)
#
#  batch_normalization_1006 (Batc  (None, 1, 1, 256)   768         ['conv2d_1006[0][0]']
#  hNormalization)
#
#  activation_1006 (Activation)   (None, 1, 1, 192)    0           ['batch_normalization_1003[0][0]'
#                                                                  ]
#
#  activation_1009 (Activation)   (None, 1, 1, 256)    0           ['batch_normalization_1006[0][0]'
#                                                                  ]
#
#  block8_8_mixed (Concatenate)   (None, 1, 1, 448)    0           ['activation_1006[0][0]',
#                                                                   'activation_1009[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 1, 1, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 1, 1, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 1, 1, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_1008 (Conv2D)           (None, 1, 1, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_1008 (Batc  (None, 1, 1, 192)   576         ['conv2d_1008[0][0]']
#  hNormalization)
#
#  soft_attention (SoftAttention)  [(None, 1, 1, 192),  27664      ['batch_normalization_1008[0][0]'
#                                  (None, 16, 1, 1)]               ]
#
#  max_pooling2d_27 (MaxPooling2D  (None, 1, 1, 192)   0           ['batch_normalization_1008[0][0]'
#  )                                                               ]
#
#  max_pooling2d_26 (MaxPooling2D  (None, 1, 1, 192)   0           ['soft_attention[0][0]']
#  )
#
#  concatenate_3 (Concatenate)    (None, 1, 1, 384)    0           ['max_pooling2d_27[0][0]',
#                                                                   'max_pooling2d_26[0][0]']
#
#  activation_1018 (Activation)   (None, 1, 1, 384)    0           ['concatenate_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 1, 1, 384)    0           ['activation_1018[0][0]']
#
#  flatten_3 (Flatten)            (None, 384)          0           ['dropout_3[0][0]']
#
#  dense_3 (Dense)                (None, 7)            2695        ['flatten_3[0][0]']
#
# ==================================================================================================
# Total params: 47,494,967
# Trainable params: 47,440,567
# Non-trainable params: 54,400
# __________________________________________________________________________________________________

# %%
opt1=tf.keras.optimizers.Adam(learning_rate=0.01,epsilon=0.1)
model.compile(optimizer=opt1,
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
class_weights = {   
                    0: 1.0,  # akiec
                    1: 1.0,  # bcc
                    2: 1.0,  # bkl
                    3: 1.0,  # df
                    4: 5.0,  # mel
                    5: 1.0,  # nv
                    6: 1.0,  # vasc
                }


checkpoint=  ModelCheckpoint(filepath ='IRV2+SA.hdf5',monitor='val_accuracy',save_best_only=True,save_weights_only=True)

# %%
Earlystop = EarlyStopping(monitor='val_loss', mode='min',patience=30, min_delta=0.001)
history = model.fit(train_batches,
                    steps_per_epoch=(len(train_df)/10),
                    epochs=150,
                    verbose=2,
                    validation_data=test_batches,validation_steps=len(test_df)/batch_size,callbacks=[checkpoint,Earlystop],class_weight=class_weights)
# Out:
# Epoch 1/150
# 918/918 - 5400s - loss: 6.6026 - accuracy: 0.1608 - val_loss: 5.5956 - val_accuracy: 0.0471 - 5400s/epoch - 6s/step
# Epoch 2/150
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-1574c4148162> in <module>
#       4                     epochs=150,
#       5                     verbose=2,
# ----> 6                     validation_data=test_batches,validation_steps=len(test_df)/batch_size,callbacks=[checkpoint,Earlystop],class_weight=class_weights)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
from tensorflow.keras import models
model.load_weights("IRV2+SA.hdf5")

# %%
predictions = model.predict(test_batches, steps=len(test_df)/batch_size, verbose=0)

# %%
#geting predictions on test dataset
y_pred = np.argmax(predictions, axis=1)
targetnames = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
#getting the true labels per image 
y_true = test_batches.classes
#getting the predicted labels per image 
y_prob=predictions
from tensorflow.keras.utils import to_categorical
y_test = to_categorical(y_true)

# Creating classification report 
report = classification_report(y_true, y_pred, target_names=targetnames)

print("\nClassification Report:")
print(report)

# %%
print("Precision: "+ str(precision_score(y_true, y_pred, average='weighted')))
print("Recall: "+ str(recall_score(y_true, y_pred, average='weighted')))
print("Accuracy: " + str(accuracy_score(y_true, y_pred)))
print("weighted Roc score: " + str(roc_auc_score(y_true,y_prob,multi_class='ovr',average='weighted')))

# %%
model.predict(next(test_batches)[0])
